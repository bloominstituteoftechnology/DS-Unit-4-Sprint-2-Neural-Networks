# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>
# <br></br>
# <br></br>
#
# # *Data Science Unit 4 Sprint 2 Assignment 1*
#
# Use TensorFlow Keras & a sample of the [Quickdraw dataset](https://github.com/googlecreativelab/quickdraw-dataset) to build a sketch classification model. The dataset has been sampled to only 10 classes and 10000 observations per class. Please build a baseline classification model then run a few experiments with different optimizers and learning rates.
#
# *Don't forgot to switch to GPU on Colab!*

# %% [markdown]
# ## Load Your Data

# %%
import numpy as np
import tensorflow as tf 

data = np.load('/Users/matthewdmeans/unit4/DS-Unit-4-Sprint-2-Neural-Networks/quickdraw10.npz')
X = data['arr_0']
y = data['arr_1']

print(X.shape)
print(y.shape)
# Out:
# (100000, 784)
# (100000,)

# %%
class_names = ['apple',
 'anvil',
 'airplane',
 'banana',
 'The Eiffel Tower',
 'The Mona Lisa',
 'The Great Wall of China',
 'alarm clock',
 'ant',
 'asparagus']

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
start = 0

for num, name in enumerate(class_names):
    plt.subplot(2,5, num+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X[start].reshape(28,28), cmap=plt.cm.binary)
    plt.xlabel(name)
    start += 10000
plt.show()

# %%
# Need this line to randomly shuffle both the X & y at the same time.

from sklearn.utils import shuffle
X, y = shuffle(X, y)

# %% [markdown]
# ## Build Your Baseline Model
# Some Hints:
#
#
# *  Model should have 784 input values (like mnist)
# *  Use `sparse_categorical_crossentropy` as your loss function.
# * You need 10 neurons in your last layer for output
# * You can add as many hidden layers with as many neurons in them as you like.
# * Limit your model epochs to 30 each time you fit.
# * You can use the `validation_split` command to automatically create a training / validation dataset.  Specify a percentage such as .2 in your fit statement.

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split

# %%
model = Sequential()

# %%
model.add(
    Dense(32, activation='relu', input_dim=784))

model.add(
    Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                25120
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                330
# =================================================================
# Total params: 25,450
# Trainable params: 25,450
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=.2)

# %%
baseline = model.fit(X_train, y_train, epochs=30, validation_data=(X_val, y_val))
# Out:
# Epoch 1/30
# 2500/2500 [==============================] - 3s 1ms/step - loss: 2.6615 - accuracy: 0.3105 - val_loss: 1.7397 - val_accuracy: 0.3632
# Epoch 2/30
# 2500/2500 [==============================] - 3s 1ms/step - loss: 1.6321 - accuracy: 0.3921 - val_loss: 1.5617 - val_accuracy: 0.4209
# Epoch 3/30
# 2500/2500 [==============================] - 4s 1ms/step - loss: 1.4608 - accuracy: 0.4525 - val_loss: 1.4102 - val_accuracy: 0.4760
# Epoch 4/30
# 2500/2500 [==============================] - 4s 1ms/step - loss: 1.3275 - accuracy: 0.5024 - val_loss: 1.3065 - val_accuracy: 0.5118
# Epoch 5/30
# 2500/2500 [==============================] - 3s 1ms/step - loss: 1.2490 - accuracy: 0.5304 - val_loss: 1.2333 - val_accuracy: 0.5501
# Epoch 6/30
# 2500/2500 [==============================] - 3s 1ms/step - loss: 1.2062 - accuracy: 0.5556 - val_loss: 1.2010 - val_accuracy: 0.5528: 0s - loss: 1.2067 - accuracy: 0.55
# Epoch 7/30
# 2500/2500 [==============================] - 3s 1ms/step - loss: 1.1605 - accuracy: 0.5742 - val_loss: 1.1603 - val_accuracy: 0.5840
# Epoch 8/30
# 2500/2500 [==============================] - 3s 1ms/step - loss: 1.1257 - accuracy: 0.5883 - val_loss: 1.1280 - val_accuracy: 0.5913
# Epoch 9/30
# 2500/2500 [==============================] - 3s 1ms/step - loss: 1.0996 - accuracy: 0.5979 - val_loss: 1.1123 - val_accuracy: 0.5968
# Epoch 10/30
# 2500/2500 [==============================] - 3s 1ms/step - loss: 1.0730 - accuracy: 0.6195 - val_loss: 1.1519 - val_accuracy: 0.6173
# Epoch 11/30
# 2500/2500 [==============================] - 3s 1ms/step - loss: 1.0345 - accuracy: 0.6567 - val_loss: 1.0698 - val_accuracy: 0.6816
# Epoch 12/30
# 2500/2500 [==============================] - 4s 2ms/step - loss: 0.9767 - accuracy: 0.6967 - val_loss: 1.0271 - val_accuracy: 0.6898
# Epoch 13/30
# 2500/2500 [==============================] - 4s 1ms/step - loss: 0.9446 - accuracy: 0.7104 - val_loss: 1.0144 - val_accuracy: 0.7112
# Epoch 14/30
# 2500/2500 [==============================] - 4s 1ms/step - loss: 0.9284 - accuracy: 0.7173 - val_loss: 0.9792 - val_accuracy: 0.7113
# Epoch 15/30
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.9231 - accuracy: 0.7187 - val_loss: 1.0440 - val_accuracy: 0.6809
# Epoch 16/30
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.9187 - accuracy: 0.7176 - val_loss: 0.9841 - val_accuracy: 0.7130
# Epoch 17/30
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.9164 - accuracy: 0.7197 - val_loss: 0.9977 - val_accuracy: 0.7153
# Epoch 18/30
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.9096 - accuracy: 0.7190 - val_loss: 1.0386 - val_accuracy: 0.7035
# Epoch 19/30
# 2500/2500 [==============================] - 4s 1ms/step - loss: 0.9105 - accuracy: 0.7189 - val_loss: 0.9961 - val_accuracy: 0.7115
# Epoch 20/30
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.9092 - accuracy: 0.7186 - val_loss: 1.0181 - val_accuracy: 0.7116
# Epoch 21/30
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.9063 - accuracy: 0.7190 - val_loss: 1.0074 - val_accuracy: 0.7006
# Epoch 22/30
# 2500/2500 [==============================] - 4s 1ms/step - loss: 0.9030 - accuracy: 0.7159 - val_loss: 1.0442 - val_accuracy: 0.7079
# Epoch 23/30
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.8997 - accuracy: 0.7147 - val_loss: 1.0137 - val_accuracy: 0.7121
# Epoch 24/30
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.8985 - accuracy: 0.7201 - val_loss: 1.0142 - val_accuracy: 0.6952
# Epoch 25/30
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.8891 - accuracy: 0.7262 - val_loss: 1.0500 - val_accuracy: 0.7153
# Epoch 26/30
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.8774 - accuracy: 0.7345 - val_loss: 1.0514 - val_accuracy: 0.6980
# Epoch 27/30
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.8686 - accuracy: 0.7375 - val_loss: 0.9405 - val_accuracy: 0.7310
# Epoch 28/30
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.8661 - accuracy: 0.7394 - val_loss: 0.9627 - val_accuracy: 0.7211
# Epoch 29/30
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.8610 - accuracy: 0.7394 - val_loss: 0.9696 - val_accuracy: 0.7211
# Epoch 30/30
# 2500/2500 [==============================] - 3s 1ms/step - loss: 0.8593 - accuracy: 0.7403 - val_loss: 0.9651 - val_accuracy: 0.7235

# %%
model.evaluate(X_val, y_val)
# Out:
# 625/625 [==============================] - 1s 829us/step - loss: 0.9651 - accuracy: 0.7235
# [0.9651052951812744, 0.7234500050544739]

# %% [markdown]
# ### Visualize the results
#
# Create charts for both loss and accuracy by epoch. Use line graphs for both charts. Analyze the results.
#
# At what point should we have stopped training the model and why?

# %%
baseline.history
# Out:
# {'loss': [2.661486864089966,
#   1.6320992708206177,
#   1.4607843160629272,
#   1.3274955749511719,
#   1.2489874362945557,
#   1.206242561340332,
#   1.1604547500610352,
#   1.1256980895996094,
#   1.0996276140213013,
#   1.073042631149292,
#   1.0344736576080322,
#   0.976701557636261,
#   0.9445891380310059,
#   0.9283702969551086,
#   0.9230642318725586,
#   0.9187437295913696,
#   0.9163591861724854,
#   0.9096071124076843,
#   0.9105319380760193,
#   0.9092327356338501,
#   0.906319260597229,
#   0.9029945135116577,
#   0.8997140526771545,
#   0.8985099792480469,
#   0.8890542984008789,
#   0.8773924112319946,
#   0.8685606718063354,
#   0.866065263748169,
#   0.8609645366668701,
#   0.8592884540557861],
#  'accuracy': [0.31052500009536743,
#   0.3921250104904175,
#   0.45253750681877136,
#   0.502387523651123,
#   0.5303624868392944,
#   0.5556374788284302,
#   0.5742499828338623,
#   0.5883125066757202,
#   0.5978624820709229,
#   0.6194999814033508,
#   0.6566500067710876,
#   0.6966999769210815,
#   0.7103875279426575,
#   0.71732497215271,
#   0.7186874747276306,
#   0.7175874710083008,
#   0.7196999788284302,
#   0.7189624905586243,
#   0.7189124822616577,
#   0.7186375260353088,
#   0.7190374732017517,
#   0.715862512588501,
#   0.7147499918937683,
#   0.7200999855995178,
#   0.7261624932289124,
#   0.7345250248908997,
#   0.7374749779701233,
#   0.7393624782562256,
#   0.7393875122070312,
#   0.740262508392334],
#  'val_loss': [1.739688515663147,
#   1.5616878271102905,
#   1.4102267026901245,
#   1.3064680099487305,
#   1.23329496383667,
#   1.2009992599487305,
#   1.160272479057312,
#   1.1279776096343994,
#   1.1123250722885132,
#   1.1518657207489014,
#   1.0698424577713013,
#   1.0270718336105347,
#   1.014360785484314,
#   0.9792446494102478,
#   1.0439702272415161,
#   0.9840647578239441,
#   0.9977239966392517,
#   1.038583755493164,
#   0.9961087107658386,
#   1.0181423425674438,
#   1.0073689222335815,
#   1.0441783666610718,
#   1.0137161016464233,
#   1.014188289642334,
#   1.0499546527862549,
#   1.0513849258422852,
#   0.9404827952384949,
#   0.9627282023429871,
#   0.9695873260498047,
#   0.9651052951812744],
#  'val_accuracy': [0.3632499873638153,
#   0.42089998722076416,
#   0.4760499894618988,
#   0.5118499994277954,
#   0.5501499772071838,
#   0.5527999997138977,
#   0.5840499997138977,
#   0.5912500023841858,
#   0.596750020980835,
#   0.6172500252723694,
#   0.6815500259399414,
#   0.6898000240325928,
#   0.7111999988555908,
#   0.7112500071525574,
#   0.6809499859809875,
#   0.7129999995231628,
#   0.7152500152587891,
#   0.7035499811172485,
#   0.7115499973297119,
#   0.7116000056266785,
#   0.7005500197410583,
#   0.7079499959945679,
#   0.7121000289916992,
#   0.6951500177383423,
#   0.7153499722480774,
#   0.6980000138282776,
#   0.7310000061988831,
#   0.7211499810218811,
#   0.7210999727249146,
#   0.7234500050544739]}

# %%
import seaborn as sns
import pandas as pd

df = pd.DataFrame.from_records(baseline.history)
df['epoch'] = [i for i in range(df.shape[0])]

ax = sns.lineplot(x='epoch', y='val_loss', data=df)
ax = sns.lineplot(x='epoch', y='loss', data=df);

# %% [markdown]
# ## Change Optimizers
# Try using the keras `adam` optimizer instead of `sgd` in your model. Visualize the difference in validation loss between the models with different optimizers.

# %%
from tf.keras.optimizers import Adam

adam = Adam()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-7966c6b03013> in <module>
# ----> 1 from tf.keras.optimizers import Adam
#       2
#       3 adam = Adam()
#
# ModuleNotFoundError: No module named 'tf'

# %% [markdown]
# ### Additional Written Tasks:
# In this section, you will need to search for resources:
# 1. Investigate the various [loss functions](https://www.tensorflow.org/api_docs/python/tf/keras/losses). Which is best suited for the task at hand (predicting 1 / 0) and why?
# 2. What is the difference between a loss function and a metric? Why might we need both in Keras?
# 3. Investigate the various [optimizers](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers). Stochastic Gradient Descent (`sgd`) is not the learning algorithm dejour anyone. Why is that? What do newer optimizers such as `adam` have to offer?

# %% [markdown]
# ## Stretch Goals:
#
# - Research convolutional neural networks and try including convolution layers in your network.
# - Pick two classes and make QuickDraw a binary classification problem, how does your model architecture change?
# - Implement Cross Validation model evaluation on your Quickdraw implementation
#
# Watch some more videos on Gradient Descent:
# - [Gradient Descent, Step-by-Step](https://www.youtube.com/watch?v=sDv4f4s2SB8)  by StatQuest w/ Josh Starmer. This will help you understand the gradient descent based optimization that happens underneath the hood of neural networks. It uses a non-neural network example, which I believe is a gentler introduction. You will hear me refer to this technique as "vanilla" gradient descent.
# - [Stochastic Gradient Descent, Clearly Explained!!!](https://www.youtube.com/watch?v=vMh0zPT0tLI) by StatQuest w/ Josh Starmer. This builds on the techniques in the previous video.  This technique is the one that is actually implemented inside modern 'nets.
# - [Siraj Raval the evolution of gradient descent](https://www.youtube.com/watch?v=nhqo0u1a6fw)
